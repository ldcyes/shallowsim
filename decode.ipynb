# %%
import os,sys
import warnings
sys.path.insert(1, os.path.join(os.getcwd()  , '..'))
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
import shallowsim as sb
import pandas as pd
import math

# %%
args = sb.ModelArgs()
c = sb.Config()
c.bs_list=[16,32,64,128,256,512,1024,2048]
gpu_blackwell_decode = sb.get_gpu_info('./device/gpu_info.csv', 
                                    decoding_mode=True, print_console=True) 

#gpu_blackwell_decode['H20'].pcie_bw = 25 #change bw to 1.6Tbps..
# Out:
# | gpu_type      |   sm |   comm_sm |   fp16 |   fp8 |   fp4 |   mem |   mem_bw |   nvlink_bw |   pcie_bw |   gpu_per_node |
# |:--------------|-----:|----------:|-------:|------:|------:|------:|---------:|------------:|----------:|---------------:|
# | DGX-B300      |  160 |        20 |   3375 |  7500 | 15000 |   288 |     8000 |         900 |       100 |              8 |
# | DGX-B200      |  160 |        20 |   2250 |  4500 |  9000 |   180 |     8000 |         900 |       100 |              8 |
# | GB200-NVL72   |  160 |        20 |   2500 |  5000 | 10000 |   192 |     8000 |         900 |       100 |             72 |
# | GB300-NVL72   |  160 |        20 |   3750 |  7500 | 15000 |   288 |     8000 |         900 |       100 |             72 |
# | Rubin-NVL144  |  110 |        12 |   6400 | 12800 | 25600 |   144 |     6500 |         900 |       100 |            144 |
# | RubinU-NVL576 |  110 |        12 |   6500 | 13000 | 26000 |   256 |     8000 |        1350 |       100 |            576 |
# | H200          |  132 |        20 |    989 |  1979 |     0 |   141 |     4800 |         450 |        50 |              8 |
# | H800          |  132 |        20 |    989 |  1979 |     0 |    80 |     4000 |         200 |        50 |              8 |
# | H20           |   78 |        10 |    148 |   296 |     0 |    96 |     4000 |         450 |        50 |              8 |
# | H20-3E        |   78 |        10 |    148 |   296 |     0 |   141 |     4800 |         450 |        50 |              8 |
# | MI300X        |  304 |        30 |   1307 |  2614 |     0 |   192 |     5300 |         448 |        50 |              8 |
# | MI308X        |  304 |        30 |    190 |   380 |     0 |   192 |     5300 |         448 |        50 |              8 |

# %%
dfs = sb.decode_time_with_ep_list(args,gpu_blackwell_decode,c,print_console=False,fp8_combine=True,tps_limit=0)

# %% [markdown]
# # 推理性能天梯榜

# %%
dfs_o = dfs.groupby(['GPU','BatchSize'],as_index=False).apply(lambda t: t[t.TPS_GPU==t.TPS_GPU.max()]).sort_values(['TPS_GPU'],ascending=False).reset_index(drop=True)
dfs_o.style.bar(subset=['TPS_USER','TPS_GPU'],color='#6495ED')\
      .applymap(sb.gpu_category_color,props=sb.gpu_category_idx(gpu_blackwell_decode),subset=['GPU'])\
      .applymap(sb.color_positive_red, subset=['Delta'])\
      .background_gradient(subset=['Comm_Impact'],cmap=sb.cm)\
      .format(precision=3)

# %% [markdown]
# # 查看单个GPU的性能

# %%
sb.df_filter(dfs,'Rubin-NVL144',0).style\
      .bar(subset=['TPS_USER','TPS_GPU'],color='#6495ED')\
      .applymap(sb.color_positive_red, subset=['Delta'])\
      .background_gradient(subset=['Comm_Impact'],cmap=sb.cm)\
      .format(precision=3)
# Out:
{
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_00665_row1_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 24.7%, transparent 24.7%);
# }
# #T_00665_row1_col18, #T_00665_row2_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 5.0%, transparent 5.0%);
# }
# #T_00665_row2_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 24.8%, transparent 24.8%);
# }
# #T_00665_row3_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 23.7%, transparent 23.7%);
# }
# #T_00665_row3_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 9.6%, transparent 9.6%);
# }
# #T_00665_row4_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 23.3%, transparent 23.3%);
# }
# #T_00665_row4_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 9.4%, transparent 9.4%);
# }
# #T_00665_row5_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 21.7%, transparent 21.7%);
# }
# #T_00665_row5_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 17.5%, transparent 17.5%);
# }
# #T_00665_row6_col16, #T_00665_row42_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 18.3%, transparent 18.3%);
# }
# #T_00665_row6_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 29.5%, transparent 29.5%);
# }
# #T_00665_row7_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 40.4%, transparent 40.4%);
# }
# #T_00665_row7_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 8.2%, transparent 8.2%);
# }
# #T_00665_row8_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 38.5%, transparent 38.5%);
# }
# #T_00665_row8_col18, #T_00665_row9_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 7.8%, transparent 7.8%);
# }
# #T_00665_row9_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 38.6%, transparent 38.6%);
# }
# #T_00665_row10_col16, #T_00665_row27_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 37.4%, transparent 37.4%);
# }
# #T_00665_row10_col18, #T_00665_row41_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 15.1%, transparent 15.1%);
# }
# #T_00665_row11_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 36.4%, transparent 36.4%);
# }
# #T_00665_row11_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 14.7%, transparent 14.7%);
# }
# #T_00665_row12_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 36.7%, transparent 36.7%);
# }
# #T_00665_row12_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 14.8%, transparent 14.8%);
# }
# #T_00665_row13_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 32.2%, transparent 32.2%);
# }
# #T_00665_row13_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 26.0%, transparent 26.0%);
# }
# #T_00665_row14_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 32.6%, transparent 32.6%);
# }
# #T_00665_row14_col18, #T_00665_row34_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 26.3%, transparent 26.3%);
# }
# #T_00665_row15_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 26.6%, transparent 26.6%);
# }
# #T_00665_row15_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 43.0%, transparent 43.0%);
# }
# #T_00665_row16_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 19.6%, transparent 19.6%);
# }
# #T_00665_row16_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 63.3%, transparent 63.3%);
# }
# #T_00665_row17_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 58.9%, transparent 58.9%);
# }
# #T_00665_row17_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 11.9%, transparent 11.9%);
# }
# #T_00665_row18_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 54.8%, transparent 54.8%);
# }
# #T_00665_row18_col18, #T_00665_row19_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 11.1%, transparent 11.1%);
# }
# #T_00665_row19_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 55.1%, transparent 55.1%);
# }
# #T_00665_row20_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 52.2%, transparent 52.2%);
# }
# #T_00665_row20_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 21.1%, transparent 21.1%);
# }
# #T_00665_row21_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 50.3%, transparent 50.3%);
# }
# #T_00665_row21_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 20.3%, transparent 20.3%);
# }
# #T_00665_row22_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 50.8%, transparent 50.8%);
# }
# #T_00665_row22_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 20.5%, transparent 20.5%);
# }
# #T_00665_row23_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 44.6%, transparent 44.6%);
# }
# #T_00665_row23_col18 {
#   width: 10em;
#   background: linear-gr

# %%
gpu = 'H20'
tps_limit = 1

tdf = sb.df_filter(dfs,gpu,tps_limit=tps_limit)
sb.df_sort(tdf,value='TPS_GPU',ascending=False).style\
     .bar(subset=['TPS_USER','TPS_GPU'],color='#6495ED')\
     .applymap(sb.color_positive_red, subset=['Delta'])\
     .background_gradient(subset=['Comm_Impact'],cmap=sb.cm)\
     .format(precision=3)
# Out:
# <style type="text/css">
# #T_81537_row0_col13, #T_81537_row1_col13, #T_81537_row2_col13, #T_81537_row3_col13, #T_81537_row4_col13, #T_81537_row5_col13, #T_81537_row6_col13, #T_81537_row7_col13, #T_81537_row8_col13, #T_81537_row9_col13, #T_81537_row10_col13, #T_81537_row11_col13, #T_81537_row12_col13, #T_81537_row13_col13, #T_81537_row14_col13, #T_81537_row15_col13, #T_81537_row16_col13, #T_81537_row17_col13, #T_81537_row18_col13, #T_81537_row19_col13, #T_81537_row20_col13, #T_81537_row21_col13, #T_81537_row22_col13, #T_81537_row23_col13 {
#   color: black;
# }
# #T_81537_row0_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 69.6%, transparent 69.6%);
# }
# #T_81537_row0_col18, #T_81537_row7_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 100.0%, transparent 100.0%);
# }
# #T_81537_row0_col20, #T_81537_row1_col20, #T_81537_row2_col20, #T_81537_row3_col20, #T_81537_row4_col20, #T_81537_row5_col20, #T_81537_row6_col20, #T_81537_row7_col20, #T_81537_row8_col20, #T_81537_row9_col20, #T_81537_row10_col20, #T_81537_row11_col20, #T_81537_row12_col20, #T_81537_row13_col20, #T_81537_row14_col20, #T_81537_row15_col20, #T_81537_row16_col20, #T_81537_row17_col20, #T_81537_row18_col20, #T_81537_row19_col20, #T_81537_row20_col20, #T_81537_row21_col20, #T_81537_row22_col20, #T_81537_row23_col20 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_81537_row1_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 34.1%, transparent 34.1%);
# }
# #T_81537_row1_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 97.8%, transparent 97.8%);
# }
# #T_81537_row2_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 32.9%, transparent 32.9%);
# }
# #T_81537_row2_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 94.6%, transparent 94.6%);
# }
# #T_81537_row3_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 63.3%, transparent 63.3%);
# }
# #T_81537_row3_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 90.9%, transparent 90.9%);
# }
# #T_81537_row4_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 30.1%, transparent 30.1%);
# }
# #T_81537_row4_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 86.4%, transparent 86.4%);
# }
# #T_81537_row5_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 54.5%, transparent 54.5%);
# }
# #T_81537_row5_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 78.3%, transparent 78.3%);
# }
# #T_81537_row6_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 26.1%, transparent 26.1%);
# }
# #T_81537_row6_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 74.9%, transparent 74.9%);
# }
# #T_81537_row7_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 71.8%, transparent 71.8%);
# }
# #T_81537_row8_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 88.7%, transparent 88.7%);
# }
# #T_81537_row8_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 63.7%, transparent 63.7%);
# }
# #T_81537_row9_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 38.1%, transparent 38.1%);
# }
# #T_81537_row9_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 54.7%, transparent 54.7%);
# }
# #T_81537_row10_col16, #T_81537_row11_col16, #T_81537_row12_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 4.2%, transparent 4.2%);
# }
# #T_81537_row10_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 48.8%, transparent 48.8%);
# }
# #T_81537_row11_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 48.6%, transparent 48.6%);
# }
# #T_81537_row12_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 48.2%, transparent 48.2%);
# }
# #T_81537_row13_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 8.3%, transparent 8.3%);
# }
# #T_81537_row13_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 47.5%, transparent 47.5%);
# }
# #T_81537_row14_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 4.1%, transparent 4.1%);
# }
# #T_81537_row14_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 47.4%, transparent 47.4%);
# }
# #T_81537_row15_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 65.7%, transparent 65.7%);
# }
# #T_81537_row15_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 47.2%, transparent 47.2%);
# }
# #T_81537_row16_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 8.2%, transparent 8.2%);
# }
# #T_81537_row16_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 47.1%, transparent 47.1%);
# }
# #T_81537_row17_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 8.1%, transparent 8.1%);
# }
# #T_81537_row17_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 46.4%, transparent 46.4%);
# }
# #T_81537_row18_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 7.7%, transparent 7.7%);
# }
# #T_81537_row18_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 44.3%, transparent 44.3%);
# }
# #T_81537_row19_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 7.2%, transparent 7.2%);
# }
# #T_81537_row19_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 41.1%, transparent 41.1%);
# }
# #T_81537_row20_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 11.3%, transparent 11.3%);
# }
# #T_81537_row20_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 32.5%, transparent 32.5%);
# }
# #T_81537_row21_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 22.5%, transparent 22.5%);
# }
# #T_81537_row21_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 32.3%, transparent 32.3%);
# }
# #T_81537_row22_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 43.9%, transparent 43.9%);
# }
# #T_81537_row22_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 31.5%, transparent 31.5%);
# }
# #T_81537_row23_col16 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 25.3%, transparent 25.3%);
# }
# #T_81537_row23_col18 {
#   width: 10em;
#   background: linear-gradient(90deg, #6495ED 18.2%, transparent 18.2%);
# }
# </style>
# <table id="T_81537">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81537_level0_col0" class="col_heading level0 col0" >GPU</th>
#       <th id="T_81537_level0_col1" class="col_heading level0 col1" >TP</th>
#       <th id="T_81537_level0_col2" class="col_heading level0 col2" >EP</th>
#       <th id="T_81537_level0_col3" class="col_heading level0 col3" >BatchSize</th>
#       <th id="T_81537_level0_col4" class="col_heading level0 col4" >DenseMLA</th>
#       <th id="T_81537_level0_col5" class="col_heading level0 col5" >DenseMLP</th>
#       <th id="T_81537_level0_col6" class="col_heading level0 col6" >SparseMLA</th>
#       <th id="T_81537_level0_col7" class="col_heading level0 col7" >Combine</th>
#       <th id="T_81537_level0_col8" class="col_heading level0 col8" >SharedExpert</th>
#       <th id="T_81537_level0_col9" class="col_heading level0 col9" >RoutedExpert</th>
#       <th id="T_81537_level0_col10" class="col_heading level0 col10" >Dispatch</th>
#       <th id="T_81537_level0_col11" class="col_heading level0 col11" >COMP_SUM</th>
#       <th id="T_81537_level0_col12" class="col_heading level0 col12" >COMM_SUM</th>
#       <th id="T_81537_level0_col13" class="col_heading level0 col13" >Delta</th>
#       <th id="T_81537_level0_col14" class="col_heading level0 col14" >TPOT</th>
#       <th id="T_81537_level0_col15" class="col_heading level0 col15" >TPOT_O</th>
#       <th id="T_81537_level0_col16" class="col_heading level0 col16" >TPS</th>
#       <th id="T_81537_level0_col17" class="col_heading level0 col17" >TPS_O</th>
#       <th id="T_81537_level0_col18" class="col_heading level0 col18" >Total</th>
#       <th id="T_81537_level0_col19" class="col_heading level0 col19" >Total_O</th>
#       <th id="T_81537_level0_col20" class="col_heading level0 col20" >Com
